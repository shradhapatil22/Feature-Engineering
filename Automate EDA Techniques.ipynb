# %%
pip install pandas_profiling
# Out:
# ...
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      -------------- ------------------------ 41.0/107.3 kB 1.9 MB/s eta 0:00:01
#      ------------------------------------ - 102.4/107.3 kB 1.2 MB/s eta 0:00:01
#      ------------------------------------ 107.3/107.3 kB 882.6 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#    ---------------------------------------- 0.0/324.4 kB ? eta -:--:--
#    -- ------------------------------------- 20.5/324.4 kB ? eta -:--:--
#    ------ --------------------------------- 51.2/324.4 kB 1.3 MB/s eta 0:00:01
#    --------- ----------------------------- 81.9/324.4 kB 919.0 kB/s eta 0:00:01
#    -------------- ----------------------- 122.9/324.4 kB 901.1 kB/s eta 0:00:01
#    ------------------- ------------------ 163.8/324.4 kB 893.0 kB/s eta 0:00:01
# ...
